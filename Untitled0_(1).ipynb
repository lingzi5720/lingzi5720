# %% [markdown]
# <a href="https://colab.research.google.com/github/lingzi5720/lingzi5720/blob/main/Untitled0_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/ddrive')
# Out:
# Mounted at /content/ddrive

# %%
#!unrar x /content/ddrive/My\ Drive/project/data/signatures.rar /content/ddrive/My\ Drive/project/data

# %%
from PIL import Image
import glob  # glob 文件通配符模块
import os  # os 处理文件和目录的模块
import numpy as np  # 多维数据处理模块
# 读取图片+数据处理
def read_img(path, label):
    # os.listdir(path) 返回path指定的文件夹包含的文件或文件夹的名字的列表

    files = os.listdir(path)
    imgs = []
    labels = []
    for file_ in files:
        if file_.endswith(('png')):
            # 读取的图片
            #  待处理图片路径
            img = Image.open(path + file_)
            #  resize图片大小，入口参数为一个tuple，新的图片的大小
            img = img.resize((300, 100))

            # 将读取的图片数据加载到imgs[]列表中
            if np.array(img).shape  != (100,300):
                continue
            imgs.append(np.array(img))
            # 将图片的label加载到labels[]中，与上方的imgs索引对应
            labels.append(label)
            # 将读取的图片和labels信息，转化为numpy结构的ndarr(N维数组对象（矩阵）)数据信息
    return np.asarray(imgs, np.float32), np.asarray(labels, np.int32)

# %%
import numpy
img = Image.open('/content/ddrive/My Drive/project/data/signatures/full_forg/forgeries_2_15.png')
numpy.array(img).shape
# Out:
# (264, 594)

# %%
path = "/content/ddrive/My Drive/project/data/signatures/full_forg/"
data1, label1=read_img(path, 0)
print(data1.shape)
print(label1.shape)
path = "/content/ddrive/My Drive/project/data/signatures/full_org/"
data2, label2=read_img(path, 1)
print(data2.shape)
print(label2.shape)
# Out:
# (1248, 100, 300)
# (1248,)
# (1248, 100, 300)
# (1248,)

# %%
data = np.concatenate((data1,data2))
data = np.expand_dims(data, axis=3)
print(data.shape)
labels = np.concatenate((label1,label2))
print(labels.shape)
# Out:
# (2496, 100, 300, 1)
# (2496,)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = np.concatenate((data1,data2))
print(X.shape)
y = np.concatenate((label1,label2))
print(y.shape)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train.reshape([-1,100*300]),y_train)
knn.score(X_test.reshape([-1,100*300]),y_test)


y_ = knn.predict(X_test.reshape([-1,100*300]))

print('准确率是：', accuracy_score(y_test, y_)) 

#KNN算法实现预测
plt.figure(figsize=(24*1,36*1.0))
for i in range(25):
    axes = plt.subplot(5,5,i+1)
    axes.imshow(X_test[i],cmap='gray')
    t = y_test[i]
    p = y_[i]
    axes.set_title('True:%d\nPred:%d'%(t,p))
    axes.axis('off')
# Out:
# (2496, 100, 300)
# (2496,)
# (1996, 100, 300) (1996,) (500, 100, 300) (500,)
# 准确率是： 0.792

# %%
from sklearn.metrics import precision_score
print('精确率是：', precision_score(y_test, y_))
from sklearn.metrics import recall_score
print('召回率是：', recall_score(y_test, y_))
# Out:
# 精确率是： 0.7086834733893558
# 召回率是： 1.0

# %%
import  tensorflow as tf
from    tensorflow.keras import layers, optimizers, datasets, Sequential
import  os
from sklearn.model_selection import train_test_split

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
tf.random.set_seed(2345)

  
network = Sequential([ # 5 units of conv + max pooling
   
    layers.Conv2D(64, kernel_size=3, strides=1),
    layers.MaxPool2D(pool_size=2, strides=2),
    layers.ReLU(), # 激活函数

    layers.Conv2D(128, kernel_size=3, strides=1),
    layers.MaxPool2D(pool_size=2, strides=2),
    layers.ReLU(), # 激活函数
    
    layers.Flatten(), # 打平层，方便全连接层处理
    
    layers.Dense(128, activation='relu'), # 全连接层，120 个节点
    layers.Dense(64, activation='relu'), # 全连接层，84 节点
    layers.Dense(2) # 全连接层，10 个节点

])


def preprocess(x, y):
    # [0~1]
    x = tf.cast(x, dtype=tf.float32) / 255.
    y = tf.cast(y, dtype=tf.int32)
    return x,y


x, x_test, y,  y_test  = train_test_split(data,labels,test_size=0.2, random_state=0) 

print(x.shape, y.shape, x_test.shape, y_test.shape)


train_db = tf.data.Dataset.from_tensor_slices((x,y))
train_db = train_db.shuffle(100).map(preprocess).batch(32)

test_db = tf.data.Dataset.from_tensor_slices((x_test,y_test))
test_db = test_db.map(preprocess).batch(32)

sample = next(iter(train_db))
print('sample:', sample[0].shape, sample[1].shape,
      tf.reduce_min(sample[0]), tf.reduce_max(sample[0]))

losses = []
acces = []
def main():

    # [b, 32, 32, 3] => [b, 1, 1, 512]

    network.build(input_shape=[None, 300, 100, 1])
    
    optimizer = optimizers.Adam(lr=1e-4)

    # [1, 2] + [3, 4] => [1, 2, 3, 4]
    variables = network.trainable_variables
    for epoch in range(50):

        for step, (x,y) in enumerate(train_db):

            with tf.GradientTape() as tape:
                
                # [b, 300, 100, 1] => [b, 2]
                logits = network(x)
                # [b] => [b, 100]
                y_onehot = tf.one_hot(y, depth=2)
                # compute loss
                loss = tf.losses.categorical_crossentropy(y_onehot, logits, from_logits=True)
                loss = tf.reduce_mean(loss)

            grads = tape.gradient(loss, variables)
            optimizer.apply_gradients(zip(grads, variables))

            if step % 20 == 0:
              if step % 100 == 0:
                losses.append(loss)
              print(epoch, step, 'loss:', float(loss))



        total_num = 0
        total_correct = 0
        for x,y in test_db:

            logits = network(x)
            prob = tf.nn.softmax(logits, axis=1)
            pred = tf.argmax(prob, axis=1)
            pred = tf.cast(pred, dtype=tf.int32)

            correct = tf.cast(tf.equal(pred, y), dtype=tf.int32)
            correct = tf.reduce_sum(correct)

            total_num += x.shape[0]
            total_correct += int(correct)

        acc = total_correct / total_num
        acces.append(acc)
        print(epoch, 'acc:', acc)



if __name__ == '__main__':
    main()
# Out:
# (1996, 100, 300, 1) (1996,) (500, 100, 300, 1) (500,)
# sample: (32, 100, 300, 1) (32,) tf.Tensor(0.20784314, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#
# 34 60 loss: 0.0003213277959730476
# 34 acc: 0.978
# 35 0 loss: 0.00029461883241310716
# 35 20 loss: 0.0004635811783373356
# 35 40 loss: 0.0004079851496499032
# 35 60 loss: 0.0003620452480390668
# 35 acc: 0.974
# 36 0 loss: 0.0007371795363724232
# 36 20 loss: 0.0007125468691810966
# 36 40 loss: 0.0003715510538313538
# 36 60 loss: 0.00028193017351441085
# 36 acc: 0.978
# 37 0 loss: 0.00011893828923348337
# 37 20 loss: 0.000457087648101151
# 37 40 loss: 0.00025960474158637226
# 37 60 loss: 0.0004654747899621725
# 37 acc: 0.98
# 38 0 loss: 0.00022867949155624956
# 38 20 loss: 0.00033475563395768404
# 38 40 loss: 0.0001670868368819356
# 38 60 loss: 0.0004495417815633118
# 38 acc: 0.978
# 39 0 loss: 0.00017480514361523092
# 39 20 loss: 0.0005369700957089663
# 39 40 loss: 0.0002562606241554022
# 39 60 loss: 0.00015374623762909323
# 39 acc: 0.978
# 40 0 loss: 0.00016123519162647426
# 40 20 loss: 0.000468327576527372
# 40 40 loss: 0.0002252122649224475
# 40 60 loss: 0.00047220996930263937
# 40 acc: 0.98
# 41 0 loss: 0.0001096116320695728
# 41 20 loss: 0.0003230509755667299
# 41 40 loss: 0.00019582929962780327
# 41 60 loss: 0.0002956172975245863
# 41 acc: 0.978
# 42 0 loss: 0.00028304525767453015
# 42 20 loss: 0.000257179606705904
# 42 40 loss: 0.00031308300094679
# 42 60 loss: 0.00018163779168389738
# 42 acc: 0.98
# 43 0 loss: 0.00017774917068891227
# 43 20 loss: 0.00036701292265206575
# 43 40 loss: 0.00011856808851007372
# 43 60 loss: 0.00020682573085650802
# 43 acc: 0.98
# 44 0 loss: 0.0001969989825738594
# 44 20 loss: 0.00015867032925598323
# 44 40 loss: 0.0001750423398334533
# 44 60 loss: 0.0003691289166454226
# 44 acc: 0.98
# 45 0 loss: 0.00011461449321359396
# 45 20 loss: 0.00017729055252857506
# 45 40 loss: 0.00011390210420358926
# 45 60 loss: 0.00022447513765655458
# 45 acc: 0.98
# 46 0 loss: 0.00014681702305097133
# 46 20 loss: 0.0001492296578362584
# 46 40 loss: 0.00015013854135759175
# 46 60 loss: 0.00029057508800178766
# 46 acc: 0.98
# 47 0 loss: 0.0001311851665377617
# 47 20 loss: 0.00012471948866732419
# 47 40 loss: 9.317849617218599e-05
# 47 60 loss: 0.00022867527150083333
# 47 acc: 0.978
# 48 0 loss: 0.00019979127682745457
# 48 20 loss: 0.0001371765829389915
# 48 40 loss: 4.622623964678496e-05
# 48 60 loss: 0.00011417789937695488
# 48 acc: 0.98
# 49 0 loss: 9.323137055616826e-05
# 49 20 loss: 0.00010873217979678884
# 49 40 loss: 9.381418931297958e-05
# 49 60 loss: 0.000229025783482939
# 49 acc: 0.982

# %%
total_num = 0
total_correct = 0
y_test = []
y_ = []
for x,y in test_db:

    y_test.append(y)
    logits = network(x)
    prob = tf.nn.softmax(logits, axis=1)
    pred = tf.argmax(prob, axis=1)
    y_.append(pred)
def trans(x):
  res = []
  for i in x:
    for j in i:
      res.append(j)
  return res  

print(trans(y_test))
from sklearn.metrics import precision_score
print('精确率是：', precision_score(trans(y_test), trans(y_)))
from sklearn.metrics import recall_score
print('召回率是：', recall_score(trans(y_test), trans(y_)))
# Out:
# [<tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, nump ...
# 精确率是： 0.983739837398374
# 召回率是： 0.979757085020243

# %%
from matplotlib import pyplot as plt #as就是重新命名的意思
from matplotlib.font_manager import FontProperties #导入中文字体
#font = FontProperties(fname=r"/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc")

x = range(1, 51, 1)
y = losses
plt.figure(figsize=(10,8),dpi=80,facecolor='w') #设置图片的尺寸和外框颜色 w白色

#绘制图片
plt.plot(x,y)

xlabels = ["{}".format(i) for i in range(1, 51, 1)] #修改x轴的刻度
plt.xticks(x, xlabels) 
#plt.yticks(range(min(y),max(y)+1)) # 修改y轴刻度

#为x y 轴和图形添加标题信息
plt.title("loss fig")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
plt.savefig('./temp.png')
plt.show()

# %%
from matplotlib import pyplot as plt #as就是重新命名的意思
from matplotlib.font_manager import FontProperties #导入中文字体
#font = FontProperties(fname=r"/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc")

x = range(1, 51, 1)
y = acces
plt.figure(figsize=(10,8),dpi=80,facecolor='w') #设置图片的尺寸和外框颜色 w白色

#绘制图片
plt.plot(x,y)

xlabels = ["{}".format(i) for i in range(1, 51, 1)] #修改x轴的刻度
plt.xticks(x, xlabels) 
#plt.yticks(range(min(y),max(y)+1)) # 修改y轴刻度

#为x y 轴和图形添加标题信息
plt.title("acc fig")
plt.xlabel("epoch")
plt.ylabel("acc")
plt.show()
plt.savefig('./temp1.png')
plt.show()

# %%
import  tensorflow as tf
from    tensorflow.keras import layers, optimizers, datasets, Sequential
import  os
from sklearn.model_selection import train_test_split

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
tf.random.set_seed(2345)

conv_layers = [ # 5 units of conv + max pooling
    # unit 1
    layers.Conv2D(64, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.Conv2D(64, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.MaxPool2D(pool_size=[2, 2], strides=2, padding='same'),

    # unit 2
    layers.Conv2D(128, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.Conv2D(128, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.MaxPool2D(pool_size=[2, 2], strides=2, padding='same'),

    # unit 3
    layers.Conv2D(256, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.Conv2D(256, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.MaxPool2D(pool_size=[2, 2], strides=2, padding='same'),

    # unit 4
    layers.Conv2D(512, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.Conv2D(512, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.MaxPool2D(pool_size=[2, 2], strides=2, padding='same'),

    # unit 5
    layers.Conv2D(512, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.Conv2D(512, kernel_size=[3, 3], padding="same", activation=tf.nn.relu),
    layers.MaxPool2D(pool_size=[2, 2], strides=2, padding='same')

]



def preprocess(x, y):
    # [0~1]
    x = tf.cast(x, dtype=tf.float32) / 255.
    y = tf.cast(y, dtype=tf.int32)
    return x,y


x, x_test, y,  y_test  = train_test_split(data,labels,test_size=0.2, random_state=0) 

print(x.shape, y.shape, x_test.shape, y_test.shape)


train_db = tf.data.Dataset.from_tensor_slices((x,y))
train_db = train_db.shuffle(1000).map(preprocess).batch(32)

test_db = tf.data.Dataset.from_tensor_slices((x_test,y_test))
test_db = test_db.map(preprocess).batch(32)

sample = next(iter(train_db))
print('sample:', sample[0].shape, sample[1].shape,
      tf.reduce_min(sample[0]), tf.reduce_max(sample[0]))

losses = []
acces = []

def main():

    # [b, 32, 32, 3] => [b, 1, 1, 512]
    conv_net = Sequential(conv_layers)

    fc_net = Sequential([
        layers.Dense(256, activation=tf.nn.relu),
        layers.Dense(128, activation=tf.nn.relu),
        layers.Dense(2, activation=None),
    ])

    conv_net.build(input_shape=[None, 300, 100, 1])
    fc_net.build(input_shape=[None, 512*10*4])
    optimizer = optimizers.Adam(lr=1e-4)

    # [1, 2] + [3, 4] => [1, 2, 3, 4]
    variables = conv_net.trainable_variables + fc_net.trainable_variables

    for epoch in range(50):

        for step, (x,y) in enumerate(train_db):

            with tf.GradientTape() as tape:
                # [b, 32, 32, 3] => [b, 1, 1, 512]
                out = conv_net(x)
                # flatten, => [b, 512]
                out = tf.reshape(out, [-1, 512*10*4])
                # [b, 512] => [b, 100]
                logits = fc_net(out)
                # [b] => [b, 100]
                y_onehot = tf.one_hot(y, depth=2)
                # compute loss
                loss = tf.losses.categorical_crossentropy(y_onehot, logits, from_logits=True)
                loss = tf.reduce_mean(loss)

            grads = tape.gradient(loss, variables)
            optimizer.apply_gradients(zip(grads, variables))

            if step %50 == 0:
              if step % 100 == 0:
                losses.append(loss)
              print(epoch, step, 'loss:', float(loss))



        total_num = 0
        total_correct = 0
        for x,y in test_db:

            out = conv_net(x)
            out = tf.reshape(out, [-1, 512*10*4])
            logits = fc_net(out)
            prob = tf.nn.softmax(logits, axis=1)
            pred = tf.argmax(prob, axis=1)
            pred = tf.cast(pred, dtype=tf.int32)

            correct = tf.cast(tf.equal(pred, y), dtype=tf.int32)
            correct = tf.reduce_sum(correct)

            total_num += x.shape[0]
            total_correct += int(correct)

        acc = total_correct / total_num
        acces.append(acc)
        print(epoch, 'acc:', acc)



if __name__ == '__main__':
    main()
# Out:
# (1996, 100, 300, 1) (1996,) (500, 100, 300, 1) (500,)
# sample: (32, 100, 300, 1) (32,) tf.Tensor(0.20784314, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 0 0 loss: 0.6930254697799683
# 0 50 loss: 0.695977509021759
# 0 acc: 0.494
# 1 0 loss: 0.6930256485939026
# 1 50 loss: 0.6913883686065674
# 1 acc: 0.496
# 2 0 loss: 0.691805362701416
# 2 50 loss: 0.6869137287139893
# 2 acc: 0.686
# 3 0 loss: 0.5658316612243652
# 3 50 loss: 0.31611934304237366
# 3 acc: 0.914
# 4 0 loss: 0.2044779360294342
# 4 50 loss: 0.03607206419110298
# 4 acc: 0.984
# 5 0 loss: 0.030926112085580826
# 5 50 loss: 0.0228830985724926
# 5 acc: 0.986
# 6 0 loss: 0.051578089594841
# 6 50 loss: 0.08137444406747818
# 6 acc: 0.994
# 7 0 loss: 0.22693878412246704
# 7 50 loss: 0.007804366294294596
# 7 acc: 0.994
# 8 0 loss: 0.017969710752367973
# 8 50 loss: 0.014841971918940544
# 8 acc: 0.994
# 9 0 loss: 0.006275766994804144
# 9 50 loss: 0.012878188863396645
# 9 acc: 0.996
# 10 0 loss: 0.002108002081513405
# 10 50 loss: 0.003640043316408992
# 10 acc: 0.994
# 11 0 loss: 0.002617430407553911
# 11 50 loss: 0.02188785746693611
# 11 acc: 0.996
# 12 0 loss: 0.001354004954919219
# 40 0 loss: 1.7061425978681655e-06
# 40 50 loss: 9.685747670573619e-08
# 40 acc: 0.998
# 41 0 loss: 2.831217216225923e-07
# 41 50 loss: 1.6465502312712488e-06
# 41 acc: 0.998
# 42 0 loss: 1.4901160305669237e-08
# 42 50 loss: 7.823104652970869e-08
# 42 acc: 0.998
# 43 0 loss: 2.101029167533852e-06
# 43 50 loss: 4.8428766774577525e-08
# 43 acc: 0.998
# 44 0 loss: 2.2351740014414645e-08
# 44 50 loss: 2.5480628664809046e-06
# 44 acc: 0.998
# 45 0 loss: 3.054731223528506e-07
# 45 50 loss: 2.607702853651972e-08
# 45 acc: 0.998
# 46 0 loss: 3.6880172160635993e-07
# 46 50 loss: 3.3154972811644257e-07
# 46 acc: 0.998
# 47 0 loss: 7.823104652970869e-08
# 47 50 loss: 2.9802318834981634e-08
# 47 acc: 0.998
# 48 0 loss: 7.823106784599076e-08
# 48 50 loss: 1.1510956028359942e-06
# 48 acc: 0.998
# 49 0 loss: 2.4856954041752033e-05
# 49 50 loss: 1.627913206903031e-06
# 49 acc: 0.998

# %% [markdown]
# # 新段落

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
total_num = 0
total_correct = 0
y_test = []
y_ = []
for x,y in test_db:

    y_test.append(y)
    logits = network(x)
    prob = tf.nn.softmax(logits, axis=1)
    pred = tf.argmax(prob, axis=1)
    y_.append(pred)
def trans(x):
  res = []
  for i in x:
    for j in i:
      res.append(j)
  return res  

print(trans(y_test))
from sklearn.metrics import precision_score
print('精确率是：', precision_score(trans(y_test), trans(y_)))
from sklearn.metrics import recall_score
print('召回率是：', recall_score(trans(y_test), trans(y_)))
# Out:
# [<tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, numpy=1>, <tf.Tensor: shape=(), dtype=int32, numpy=0>, <tf.Tensor: shape=(), dtype=int32, nump ...
# 精确率是： 0.983739837398374
# 召回率是： 0.979757085020243

# %%
from matplotlib import pyplot as plt #as就是重新命名的意思
from matplotlib.font_manager import FontProperties #导入中文字体
#font = FontProperties(fname=r"/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc")

x = range(1, 51, 1)
y = losses
plt.figure(figsize=(10,8),dpi=80,facecolor='w') #设置图片的尺寸和外框颜色 w白色

#绘制图片
plt.plot(x,y)

xlabels = ["{}".format(i) for i in range(1, 51, 1)] #修改x轴的刻度
plt.xticks(x, xlabels) 
#plt.yticks(range(min(y),max(y)+1)) # 修改y轴刻度

#为x y 轴和图形添加标题信息
plt.title("loss fig")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
plt.savefig('./temp.png')
plt.show()

# %%
from matplotlib import pyplot as plt #as就是重新命名的意思
from matplotlib.font_manager import FontProperties #导入中文字体
#font = FontProperties(fname=r"/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc")

x = range(1, 51, 1)
y = acces
plt.figure(figsize=(10,8),dpi=80,facecolor='w') #设置图片的尺寸和外框颜色 w白色

#绘制图片
plt.plot(x,y)

xlabels = ["{}".format(i) for i in range(1, 51, 1)] #修改x轴的刻度
plt.xticks(x, xlabels) 
#plt.yticks(range(min(y),max(y)+1)) # 修改y轴刻度

#为x y 轴和图形添加标题信息
plt.title("acc fig")
plt.xlabel("epoch")
plt.ylabel("acc")
plt.show()
plt.savefig('./temp1.png')
plt.show()
